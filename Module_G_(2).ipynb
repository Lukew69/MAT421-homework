# %% [markdown]
# <a href="https://colab.research.google.com/github/Lukew69/MAT421-homework/blob/main/Module_G_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 21.4

# %%
#simpsons rule for Ln(x)dx from 1 to e, compared to 1
import numpy as np

a = 1
b = np.exp(1)
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.log(x)

I_simp = (h/3) * (f[0] + 2*sum(f[:n-2:2]) \
            + 4*sum(f[1:n-1:2]) + f[n-1])
err_simp = 1 - I_simp

print(I_simp)
print(err_simp)
# Out:
# 0.9999911694014229
# 8.83059857714752e-06

# %% [markdown]
# 21.5

# %%
import numpy as np
from scipy.integrate import trapz

a = 1
b = np.exp(1)
n = 11
h = (b - a) / (n - 1)
x = np.linspace(a, b, n)
f = np.log(x)

I_trapz = trapz(f,x)
I_trap = (h/2)*(f[0] + 2 * sum(f[1:n-1]) + f[n-1])

print(I_trapz)
print(I_trap)
# Out:
# 0.998447005059135
# 0.9984470050591351

# %%
from scipy.integrate import cumtrapz
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('seaborn-poster')

x = np.arange(1, np.exp(1), 0.01)
F_exact = x*np.log(x)-x
F_approx = cumtrapz(np.log(x), x)

plt.figure(figsize = (10,6))
plt.plot(x, F_exact)
plt.plot(x[1::], F_approx)
plt.grid()
plt.tight_layout()
plt.title('$F(x) = \int_0^{x} ln(y) dy$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend(['Exact with Offset', 'Approx'])
plt.show()

# %%
from scipy.integrate import quad 

I_quad, est_err_quad = \
          quad(np.log, 1, np.exp(1))
print(I_quad)
err_quad = 1 - I_quad
print(est_err_quad, err_quad)
# Out:
# 0.9999999999999998
# 1.1102230246251562e-14 2.220446049250313e-16
